# %% [markdown]
# ![Screenshot (31).png](data:image/png;base64,...)

# %% [markdown]
# **DATA CITIZENSHIP 1989 SAMPAI 2013**

# %% [markdown]
# https://docs.google.com/spreadsheets/d/1c8mcjqm4VvO_4Uug343eQu_AFdgD88u4/edit#gid=672239806

# %% [markdown]
# **INSTALL PANDAS DAN NUMPY**

# %%
# import pandas
# import numpy
# import openpyxl
# import matplotlib
# imort scikit-learn
# import tensorflow

# !pip install pandas
# !pip install numpy
# !pip install openpyxl
# !pip install matplotlib
# !pip install scikit-learn
# !pip install tensorflow

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openpyxl as xlsx
import scikit-learn. as scln

# %% [markdown]
# 1.BASIC DASAR PYTHON MENGGUNKAN GOOGLE COLAB

# %%
# tuliskan biodata dengan code python dasar

print ("nama : haris arief kamis")
print ("Prodi: Sains Data")
print ("Nim  : 310700022310035")
# Out:
# nama : haris arief kamis
# Prodi: Sains Data
# Nim  : 310700022310035

# %%
# cara mengecek python versi berapa?

import sys
print(sys.version)
# Out:
# 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]

# %%
# Buat Komentar yang gampang
print ("halo,saya ingin berkomentar!!!") # ini cara buat komentar tidak menggunakan tanda pagar(#)
#print ("halo,saya ingin berkomentar!!!") # ini cara buat komentar menggunakan tanda pagar(#)

# %% [markdown]
# 2.TYPE DATA OBJEK PYTHON

# %%
# INTEGER (int) bilangan bulat
type(11)
# Out:
# int

# %%
## FLOAT (float) bilangan yang ada titik/komanya (bilangan desimal)
type(2.13)
# Out:
# float

# %%
# STRING (str) teks atau karakte
type("hello world! 202erorr")
# Out:
# str

# %%
# BOOLEAN (bool) True/False
True
False

# %% [markdown]
# TYPE DATA BOOLEAN

# %%
# Type True
True
# Out:
# True

# %%
# Type false
False
# Out:
# False

# %%
# Latihan 1

type("20.0")
# Out:
# str

# %%
# Latihan 1

type(20.0)
# Out:
# float

# %%
# Latihan 2

type("20.0")
# Out:
# str

# %%
# Latihan 3

type(bool(6/2))
# Out:
# bool

# %%
# Latihan 4

type(6//2)
# Out:
# int

# %%
# hitung jam

print ("160 menit")
160/60
# Out:
# 160 menit
# 2.6666666666666665

# %%
# latihan 5
list1 = [1, 2, 3, 4, 3, 2, 1]
list2 = list( ("1","2", 1, 2) )
list3 = [-1,2,3,4,5,-6]

print(list1)
print(list2)
print(list3)
# Out:
# [1, 2, 3, 4, 3, 2, 1]
# ['1', '2', 1, 2]
# [-1, 2, 3, 4, 5, -6]

# %% [markdown]
# **IMPORT DATA DI GOOGLE COLAB**

# %% [markdown]
# instal pandas.numpy,matplotlib,scikit-learn,dan tensorflow

# %%
# import pandas
# import numpy
# import openpyxl
# import matplotlib
# imort scikit-learn
# import tensorflow

# !pip install pandas
# !pip install numpy
# !pip install openpyxl
# !pip install matplotlib
# !pip install scikit-learn
# !pip install tensorflow

import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
# import openpyxl as xlsx
# import scikit-learn. as scln
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)

# %%
# install pandas dengan conda
# !pip install numpy

import numpy as np
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)

# %%
# all package
# !pip list

# %%
# all function module
dir (pd)

# %%
# manual buku python
help (pd.merge)

# %% [markdown]
# **IMPORT DATA DAN BACA DATA EXCEL.CSV**

# %%
from os import read
# read_excel()

import pandas as pd
import numpy as np
#  = data yang di ambil dari google drive

df_project = pd.read_csv('/content/drive/MyDrive/BOOTCAMP DATA ANALYST - Myskill/FINAL PROJECT-#Bacht14-MySkiil/MATERI FINAL PROJECT/Data Visualization/df.csv')

print ('df_project')
# Out:
# df_project

# %%
# menampilkan 10 baris dataframe(df)
df_project.head(10)

# %%
# menampilkan informasi dataframe(df)
df_project.info()

# %%
# menampilkan beberapa baris terakhir dari sebuah dataframe.(df)
df_project.tail(5)

# %%
# menampilkan informasi statistik deskriptif dataframe(df)
df_project.describe()
# Out:
#               price  qty_ordered  before_discount  discount_amount  \
# count  5.884000e+03  5884.000000     5.884000e+03     5.884000e+03
# mean   1.062336e+06     2.304385     1.477429e+06     5.750228e+03
# std    1.929349e+06    19.828304     1.001996e+07     6.857852e+04
# min    0.000000e+00     1.000000     0.000000e+00    -3.477100e+04
# 25%    6.351000e+04     1.000000     9.280000e+04     0.000000e+00
# 50%    2.030000e+05     1.000000     2.445280e+05     0.000000e+00
# 75%    1.017900e+06     1.000000     1.247000e+06     0.000000e+00
# max    2.778200e+07  1000.000000     5.187520e+08     2.610000e+06
#
#        after_discount  is_gross     is_valid       is_net   payment_id  \
# count    5.884000e+03    5884.0  5884.000000  5884.000000  5884.000000
# mean     1.471679e+06       1.0     0.681849     0.413154     2.430829
# std      1.001861e+07       0.0     0.465798     0.492442     2.458386
# min      0.000000e+00       1.0     0.000000     0.000000     1.000000
# 25%      9.274200e+04       1.0     0.000000     0.000000     1.000000
# 50%      2.436000e+05       1.0     1.000000     0.000000     1.000000
# 75%      1.222785e+06       1.0     1.000000     1.000000     4.000000
# max      5.187520e+08       1.0     1.000000     1.000000    16.000000
#
#          base_price          cogs    month_num
# count  5.884000e+03  5.884000e+03  5884.000000
# mean   1.055451e+06  7.920283e+05     6.560503
# std    1.925075e+06  1.430209e+06     3.374759
# min    0.000000e+00  0.000000e+00     1.000000
# 25%    6.351000e+04  4.750200e+04     4.000000
# 50%    2.001000e+05  1.476100e+05     7.000000
# 75%    1.009200e+06  7.586400e+05     9.000000
# max    2.778200e+07  1.694702e+07    12.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['price'].plot(kind='hist', bins=20, title='price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['qty_ordered'].plot(kind='hist', bins=20, title='qty_ordered')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['before_discount'].plot(kind='hist', bins=20, title='before_discount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['discount_amount'].plot(kind='hist', bins=20, title='discount_amount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='price', y='qty_ordered', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='qty_ordered', y='before_discount', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='before_discount', y='discount_amount', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='discount_amount', y='after_discount', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['price'].plot(kind='line', figsize=(8, 4), title='price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['qty_ordered'].plot(kind='line', figsize=(8, 4), title='qty_ordered')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['before_discount'].plot(kind='line', figsize=(8, 4), title='before_discount')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['discount_amount'].plot(kind='line', figsize=(8, 4), title='discount_amount')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['price'].plot(kind='hist', bins=20, title='price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['qty_ordered'].plot(kind='hist', bins=20, title='qty_ordered')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['before_discount'].plot(kind='hist', bins=20, title='before_discount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['discount_amount'].plot(kind='hist', bins=20, title='discount_amount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_16.groupby('index').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_17.plot(kind='scatter', x='price', y='qty_ordered', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18.plot(kind='scatter', x='qty_ordered', y='before_discount', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19.plot(kind='scatter', x='before_discount', y='discount_amount', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20.plot(kind='scatter', x='discount_amount', y='after_discount', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_21['price'].plot(kind='line', figsize=(8, 4), title='price')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['qty_ordered'].plot(kind='line', figsize=(8, 4), title='qty_ordered')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['before_discount'].plot(kind='line', figsize=(8, 4), title='before_discount')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['discount_amount'].plot(kind='line', figsize=(8, 4), title='discount_amount')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='price', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='qty_ordered', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_27['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_27, x='before_discount', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_28['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_28, x='discount_amount', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# menampilkan filter dataframe(df) berdasarkan column
df_project.filter()

# %%
# mengelompokan dataframe(df) berdasarkan column
df_project.groupbyby()
